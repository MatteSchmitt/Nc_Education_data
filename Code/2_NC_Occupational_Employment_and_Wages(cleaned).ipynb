# %%
import pandas as pd
import numpy as np

# %%
file_path = '2_NC_Occupational_Employment_and_Wages.csv'
df2 = pd.read_csv(file_path)
df2.head()
# Out:
#         Area Name Occupational Code                           Occupation  \
# 0  North Carolina           00-0000               Total, All Occupations
# 1  North Carolina           11-0000               Management Occupations
# 2  North Carolina           11-1011                     Chief Executives
# 3  North Carolina           11-1021      General and Operations Managers
# 4  North Carolina           11-2011  Advertising and Promotions Managers
#
#    Naics Code                                           Industry  Year  \
# 0           0  Cross-industry, private, federal, state, and l...  2022
# 1           0  Cross-industry, private, federal, state, and l...  2022
# 2           0  Cross-industry, private, federal, state, and l...  2022
# 3           0  Cross-industry, private, federal, state, and l...  2022
# 4           0  Cross-industry, private, federal, state, and l...  2022
#
#   Employment  Employment Relative Standard Error  Response Rate(%)  \
# ...

# %%
df2.replace('*', np.nan, inplace=True)
df2.head()
# Out:
#         Area Name Occupational Code                           Occupation  \
# 0  North Carolina           00-0000               Total, All Occupations
# 1  North Carolina           11-0000               Management Occupations
# 2  North Carolina           11-1011                     Chief Executives
# 3  North Carolina           11-1021      General and Operations Managers
# 4  North Carolina           11-2011  Advertising and Promotions Managers
#
#    Naics Code                                           Industry  Year  \
# 0           0  Cross-industry, private, federal, state, and l...  2022
# 1           0  Cross-industry, private, federal, state, and l...  2022
# 2           0  Cross-industry, private, federal, state, and l...  2022
# 3           0  Cross-industry, private, federal, state, and l...  2022
# 4           0  Cross-industry, private, federal, state, and l...  2022
#
#   Employment  Employment Relative Standard Error  Response Rate(%)  \
# ...

# %%
df2.to_csv('2_NC_Occupational_Employment_and_Wages(cleaned)csv', index=False)

# %%
if df2['Annual wage; mean'].isnull().any():
    print("There are missing values in the 'Annual wage; mean' column.")
else:
    print("No missing values in the 'Annual wage; mean' column.")
# Out:
# There are missing values in the 'Annual wage; mean' column.

# %%
#There there is a lot of missing data, we assumed the most important column is probably [Annual wage; mean] it only has 
#some missing values so if we do run into trouble with this data we can always delete the rows with that using something
#like the code below


#this will drop our missings
df2.dropna(subset=['Annual wage; mean'], inplace=True)
df2
# Out:
#           Area Name Occupational Code  \
# 0    North Carolina           00-0000
# 1    North Carolina           11-0000
# 2    North Carolina           11-1011
# 3    North Carolina           11-1021
# 4    North Carolina           11-2011
# ..              ...               ...
# 801  North Carolina           53-7065
# 802  North Carolina           53-7072
# 803  North Carolina           53-7081
# 804  North Carolina           53-7121
# 805  North Carolina           53-7199
#
#                                     Occupation  Naics Code  \
# 0                       Total, All Occupations           0
# 1                       Management Occupations           0
# 2                             Chief Executives           0
# 3              General and Operations Managers           0
# 4          Advertising and Promotions Managers           0
# ..                                         ...         ...
# 801                 Stockers and Order Fillers           0
# ...

# %%
if df2['Annual wage; mean'].isnull().any():
    print("There are missing values in the 'Annual wage; mean' column.")
else:
    print("No missing values in the 'Annual wage; mean' column.")
# Out:
# No missing values in the 'Annual wage; mean' column.
